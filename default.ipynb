# %% [markdown]
# # French ID Detection Training
#
# This notebook implements the dataset generation and training process for French ID detection using Python 3.11.

# %% [markdown]
# ## Setup and Dependencies

# %% [markdown]
# ### 1. Go to the notebook root directory

# %%
# %cd /content

# %% [markdown]
# ### 2. Install Python 3.11 and required packages

# %%
# !apt-get update && apt-get install -y python3.11
# !python3.11 --version
# !python3.11 -m pip install jedi
# !python3.11 -m pip install --upgrade pip
# !python3.11 -m pip install --upgrade setuptools
# !python3.11 -m pip install --upgrade wheel
# !python3.11 -m pip install ultralytics
# !python3.11 -m pip install albumentations
# !python3.11 -m pip install tensorflow
# !python3.11 -m pip install tensorboard
# !python3.11 -m pip install boto3
# !pwd

# %% [markdown]
# ### 3. Clone the repository

# %%
# !git clone https://github.com/arezkisaba/french-id-detection-training.git
# !pwd

# %% [markdown]
# ### 4. Change to scripts directory

# %%
# %cd ./french-id-detection-training/src/scripts

# %% [markdown]
# ## Dataset Generation & Training Process

# %% [markdown]
# ### 1. Download OpenImages Backgrounds

# %%
# !python3.11 ./backgrounds-download.py

# %% [markdown]
# ### 2. Dataset generation

# %%
# !python3.11 ./dataset-generate.py

# %% [markdown]
# ### 3. Model training

# %%
# !python3.11 ./dataset-train.py

# %% [markdown]
# ## Results

# %% [markdown]
# ### 1. List the contents of the results directory

# %%
# !ls -la /content/french-id-detection-training/src/results/weights
